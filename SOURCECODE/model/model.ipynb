# %%
from matplotlib import pyplot as plt
import numpy as np 
import pandas as pd 

# Data Loading
data = pd.read_csv("I:/Projects/Skin-Cancer-Prediction/DATASET/hmnist_28_28_RGB.csv")
data.head()
meta_df = pd.read_csv("I:/Projects/Skin-Cancer-Prediction/DATASET/HAM10000_metadata.csv")
meta_df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
import tensorflow as tf

# Check for available GPUs
physical_devices = tf.config.list_physical_devices('GPU')

# If GPUs are available, configure session to use them
if len(physical_devices) > 0:
  tf.config.experimental.set_memory_growth(physical_devices[0], True)
  logical_devices = tf.config.list_logical_devices('GPU')

  print(logical_devices)

# %%
meta_df.shape
data.shape
# Out:
# (10015, 2353)

# %%
yData = data['label']
XData = data.drop(columns = ['label'])
# EDA
distribution = meta_df['dx'].value_counts()
distribution
# classes = {4: ('nv', ' melanocytic nevi'),
#            6: ('mel', 'melanoma'),
#            2 :('bkl', 'benign keratosis-like lesions'), 
#            1:('bcc' , ' basal cell carcinoma'),
#            5: ('vasc', ' pyogenic granulomas and hemorrhage'),
#            0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
#            3: ('df', 'dermatofibroma')}
# Out:
# dx
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: count, dtype: int64

# %%
dist = data['label'].value_counts()
dist
distribution.plot()
plt.title('Distribution of Skin Cancer Classes')
plt.show()

# %%
pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Collecting imbalanced-learn (from imblearn)
#   Downloading imbalanced_learn-0.12.4-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\s\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\s\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (1.14.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\s\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (1.5.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\s\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\s\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading imbalanced_learn-0.12.4-py3-none-any.whl (258 kB)
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.12.4 imblearn-0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Fixing Data Imbalance

from imblearn.over_sampling import RandomOverSampler 
sampler = RandomOverSampler()
XData,yData  = sampler.fit_resample(XData,yData)
XData.shape, yData.shape
XData = np.array(XData).reshape((-1, 28, 28, 3))
XData = XData / 255
XData.shape
# Out:
# (46935, 28, 28, 3)

# %%
# Create the train and validation set
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(XData,yData, test_size=0.2)
Xtrain.shape, Xtest.shape
# Out:
# ((37548, 28, 28, 3), (9387, 28, 28, 3))

# %%
# Train the model
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
import tensorflow as tf

img_width, img_height = 28,28

input_shape = (img_width, img_height, 3)

# %%
model = Sequential()
model.add(Conv2D(32, (2, 2), input_shape=input_shape))
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (2, 2)))
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (2, 2)))
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('swish'))
model.add(Dropout(0.5))
model.add(Dense(7))
model.add(Activation('softmax'))
# Out:
# C:\Users\s\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='sparse_categorical_crossentropy',
optimizer='nadam',
metrics=['accuracy'])

# %%
pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in c:\users\s\appdata\roaming\python\python312\site-packages (3.5.0)
# Requirement already satisfied: absl-py in c:\users\s\appdata\roaming\python\python312\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\s\appdata\roaming\python\python312\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\s\appdata\roaming\python\python312\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\s\appdata\roaming\python\python312\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\s\appdata\roaming\python\python312\site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in c:\users\s\appdata\roaming\python\python312\site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in c:\users\s\appdata\roaming\python\python312\site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in c:\users\s\appdata\roaming\python\python312\site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\s\appdata\roaming\python\python312\site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\s\appdata\roaming\python\python312\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\s\appdata\roaming\python\python312\site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\s\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='I:/Projects/Skin-Cancer-Prediction/SOURCECODE/model/skin.keras',
    monitor='val_accuracy',  # Ensure you're using the correct metric
    mode='max',
    save_best_only=True,
    verbose=1
)

early_stopping = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

# %%
history = model.fit(Xtrain,
                    Ytrain,
                    epochs = 100,
                    validation_data = (Xtest, Ytest),
                    callbacks=[callback, early_stopping])
# Out:
# Epoch 1/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3641 - loss: 1.5807
# Epoch 1: val_accuracy improved from -inf to 0.59934, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 29s 21ms/step - accuracy: 0.3644 - loss: 1.5802 - val_accuracy: 0.5993 - val_loss: 1.0676
# Epoch 2/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5760 - loss: 1.1033
# Epoch 2: val_accuracy improved from 0.59934 to 0.66912, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 24s 21ms/step - accuracy: 0.5760 - loss: 1.1032 - val_accuracy: 0.6691 - val_loss: 0.8796
# Epoch 3/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6466 - loss: 0.9331
# Epoch 3: val_accuracy improved from 0.66912 to 0.71759, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.6466 - loss: 0.9330 - val_accuracy: 0.7176 - val_loss: 0.7620
# Epoch 4/100
# 1171/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6965 - loss: 0.8048
# Epoch 4: val_accuracy improved from 0.71759 to 0.74901, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.6965 - loss: 0.8048 - val_accuracy: 0.7490 - val_loss: 0.6621
# Epoch 5/100
# 1171/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7259 - loss: 0.7200
# Epoch 5: val_accuracy improved from 0.74901 to 0.77373, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 24s 21ms/step - accuracy: 0.7260 - loss: 0.7199 - val_accuracy: 0.7737 - val_loss: 0.5964
# Epoch 6/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7447 - loss: 0.6643
# Epoch 6: val_accuracy improved from 0.77373 to 0.78428, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.7447 - loss: 0.6643 - val_accuracy: 0.7843 - val_loss: 0.5705
# Epoch 7/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7673 - loss: 0.6111
# Epoch 7: val_accuracy improved from 0.78428 to 0.81506, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.7673 - loss: 0.6111 - val_accuracy: 0.8151 - val_loss: 0.4968
# Epoch 8/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7830 - loss: 0.5691
# Epoch 8: val_accuracy improved from 0.81506 to 0.82913, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.7830 - loss: 0.5691 - val_accuracy: 0.8291 - val_loss: 0.4538
# Epoch 9/100
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7984 - loss: 0.5240
# Epoch 9: val_accuracy improved from 0.82913 to 0.84383, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.7984 - loss: 0.5240 - val_accuracy: 0.8438 - val_loss: 0.4193
# Epoch 10/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8151 - loss: 0.4864
# Epoch 10: val_accuracy did not improve from 0.84383
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.8151 - loss: 0.4864 - val_accuracy: 0.8417 - val_loss: 0.4163
# Epoch 11/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8222 - loss: 0.4640
# Epoch 11: val_accuracy improved from 0.84383 to 0.86598, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.8222 - loss: 0.4640 - val_accuracy: 0.8660 - val_loss: 0.3619
# Epoch 12/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8359 - loss: 0.4336
# Epoch 12: val_accuracy improved from 0.86598 to 0.87813, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.8359 - loss: 0.4336 - val_accuracy: 0.8781 - val_loss: 0.3281
# Epoch 13/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8440 - loss: 0.4062
# Epoch 13: val_accuracy did not improve from 0.87813
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.8440 - loss: 0.4062 - val_accuracy: 0.8754 - val_loss: 0.3283
# Epoch 14/100
# 1171/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8536 - loss: 0.3810
# Epoch 14: val_accuracy improved from 0.87813 to 0.87898, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 42s 23ms/step - accuracy: 0.8537 - loss: 0.3810 - val_accuracy: 0.8790 - val_loss: 0.3240
# Epoch 15/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8659 - loss: 0.3535
# Epoch 15: val_accuracy improved from 0.87898 to 0.88985, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.8659 - loss: 0.3535 - val_accuracy: 0.8898 - val_loss: 0.3083
# Epoch 16/100
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8681 - loss: 0.3440
# Epoch 16: val_accuracy improved from 0.88985 to 0.90657, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 28s 24ms/step - accuracy: 0.8681 - loss: 0.3440 - val_accuracy: 0.9066 - val_loss: 0.2545
# Epoch 17/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8772 - loss: 0.3214
# Epoch 17: val_accuracy did not improve from 0.90657
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 35s 29ms/step - accuracy: 0.8772 - loss: 0.3214 - val_accuracy: 0.8958 - val_loss: 0.2745
# Epoch 18/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8848 - loss: 0.3055
# Epoch 18: val_accuracy improved from 0.90657 to 0.92021, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 33s 28ms/step - accuracy: 0.8848 - loss: 0.3055 - val_accuracy: 0.9202 - val_loss: 0.2289
# Epoch 19/100
# 1171/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8883 - loss: 0.2900
# Epoch 19: val_accuracy improved from 0.92021 to 0.92468, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.8883 - loss: 0.2900 - val_accuracy: 0.9247 - val_loss: 0.2209
# Epoch 20/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8931 - loss: 0.2819
# Epoch 20: val_accuracy did not improve from 0.92468
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.8931 - loss: 0.2819 - val_accuracy: 0.9205 - val_loss: 0.2196
# Epoch 21/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9004 - loss: 0.2639
# Epoch 21: val_accuracy improved from 0.92468 to 0.92841, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9004 - loss: 0.2639 - val_accuracy: 0.9284 - val_loss: 0.1981
# Epoch 22/100
# 1171/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9003 - loss: 0.2633
# Epoch 22: val_accuracy improved from 0.92841 to 0.93587, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9003 - loss: 0.2632 - val_accuracy: 0.9359 - val_loss: 0.1888
# Epoch 23/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9022 - loss: 0.2549
# Epoch 23: val_accuracy improved from 0.93587 to 0.93598, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9022 - loss: 0.2549 - val_accuracy: 0.9360 - val_loss: 0.1868
# Epoch 24/100
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9133 - loss: 0.2263
# Epoch 24: val_accuracy improved from 0.93598 to 0.93885, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9133 - loss: 0.2263 - val_accuracy: 0.9389 - val_loss: 0.1828
# Epoch 25/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9102 - loss: 0.2403
# Epoch 25: val_accuracy improved from 0.93885 to 0.94066, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9103 - loss: 0.2403 - val_accuracy: 0.9407 - val_loss: 0.1779
# Epoch 26/100
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9150 - loss: 0.2240
# Epoch 26: val_accuracy improved from 0.94066 to 0.94663, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9150 - loss: 0.2240 - val_accuracy: 0.9466 - val_loss: 0.1612
# Epoch 27/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9188 - loss: 0.2123
# Epoch 27: val_accuracy improved from 0.94663 to 0.94919, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 42s 23ms/step - accuracy: 0.9188 - loss: 0.2123 - val_accuracy: 0.9492 - val_loss: 0.1551
# Epoch 28/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9246 - loss: 0.2049
# Epoch 28: val_accuracy improved from 0.94919 to 0.95291, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9246 - loss: 0.2050 - val_accuracy: 0.9529 - val_loss: 0.1518
# Epoch 29/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9238 - loss: 0.2046
# Epoch 29: val_accuracy did not improve from 0.95291
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9238 - loss: 0.2046 - val_accuracy: 0.9512 - val_loss: 0.1577
# Epoch 30/100
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9241 - loss: 0.2031
# Epoch 30: val_accuracy did not improve from 0.95291
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9241 - loss: 0.2031 - val_accuracy: 0.9511 - val_loss: 0.1527
# Epoch 31/100
# 1171/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9260 - loss: 0.1953
# Epoch 31: val_accuracy did not improve from 0.95291
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9260 - loss: 0.1953 - val_accuracy: 0.9497 - val_loss: 0.1527
# Epoch 32/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9319 - loss: 0.1856
# Epoch 32: val_accuracy improved from 0.95291 to 0.95462, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9319 - loss: 0.1856 - val_accuracy: 0.9546 - val_loss: 0.1421
# Epoch 33/100
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9287 - loss: 0.1862
# Epoch 33: val_accuracy did not improve from 0.95462
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9287 - loss: 0.1862 - val_accuracy: 0.9525 - val_loss: 0.1385
# Epoch 34/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9381 - loss: 0.1712
# Epoch 34: val_accuracy improved from 0.95462 to 0.95622, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.9381 - loss: 0.1712 - val_accuracy: 0.9562 - val_loss: 0.1339
# Epoch 35/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9370 - loss: 0.1733
# Epoch 35: val_accuracy improved from 0.95622 to 0.95792, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9370 - loss: 0.1733 - val_accuracy: 0.9579 - val_loss: 0.1309
# Epoch 36/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9381 - loss: 0.1694
# Epoch 36: val_accuracy improved from 0.95792 to 0.95856, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9381 - loss: 0.1694 - val_accuracy: 0.9586 - val_loss: 0.1250
# Epoch 37/100
# 1171/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9388 - loss: 0.1677
# Epoch 37: val_accuracy did not improve from 0.95856
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9388 - loss: 0.1677 - val_accuracy: 0.9542 - val_loss: 0.1467
# Epoch 38/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9397 - loss: 0.1595
# Epoch 38: val_accuracy improved from 0.95856 to 0.96229, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9397 - loss: 0.1595 - val_accuracy: 0.9623 - val_loss: 0.1238
# Epoch 39/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9417 - loss: 0.1572
# Epoch 39: val_accuracy did not improve from 0.96229
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9417 - loss: 0.1572 - val_accuracy: 0.9598 - val_loss: 0.1261
# Epoch 40/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9418 - loss: 0.1552
# Epoch 40: val_accuracy did not improve from 0.96229
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9418 - loss: 0.1552 - val_accuracy: 0.9593 - val_loss: 0.1280
# Epoch 41/100
# 1171/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9427 - loss: 0.1519
# Epoch 41: val_accuracy did not improve from 0.96229
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.9427 - loss: 0.1519 - val_accuracy: 0.9385 - val_loss: 0.1748
# Epoch 42/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9409 - loss: 0.1546
# Epoch 42: val_accuracy improved from 0.96229 to 0.96612, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9409 - loss: 0.1545 - val_accuracy: 0.9661 - val_loss: 0.1191
# Epoch 43/100
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9438 - loss: 0.1468
# Epoch 43: val_accuracy improved from 0.96612 to 0.96687, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9438 - loss: 0.1468 - val_accuracy: 0.9669 - val_loss: 0.1083
# Epoch 44/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9467 - loss: 0.1428
# Epoch 44: val_accuracy did not improve from 0.96687
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.9467 - loss: 0.1428 - val_accuracy: 0.9626 - val_loss: 0.1315
# Epoch 45/100
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9473 - loss: 0.1397
# Epoch 45: val_accuracy improved from 0.96687 to 0.96772, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9473 - loss: 0.1397 - val_accuracy: 0.9677 - val_loss: 0.1042
# Epoch 46/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9482 - loss: 0.1380
# Epoch 46: val_accuracy did not improve from 0.96772
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9482 - loss: 0.1380 - val_accuracy: 0.9644 - val_loss: 0.1186
# Epoch 47/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9503 - loss: 0.1315
# Epoch 47: val_accuracy did not improve from 0.96772
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9503 - loss: 0.1315 - val_accuracy: 0.9612 - val_loss: 0.1300
# Epoch 48/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9516 - loss: 0.1314
# Epoch 48: val_accuracy did not improve from 0.96772
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9516 - loss: 0.1314 - val_accuracy: 0.9670 - val_loss: 0.1101
# Epoch 49/100
# 1171/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9511 - loss: 0.1326
# Epoch 49: val_accuracy did not improve from 0.96772
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - accuracy: 0.9511 - loss: 0.1326 - val_accuracy: 0.9641 - val_loss: 0.1166
# Epoch 50/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9533 - loss: 0.1250
# Epoch 50: val_accuracy did not improve from 0.96772
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 41s 23ms/step - accuracy: 0.9533 - loss: 0.1251 - val_accuracy: 0.9663 - val_loss: 0.1093
# Epoch 51/100
# 1172/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9543 - loss: 0.1254
# Epoch 51: val_accuracy did not improve from 0.96772
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9543 - loss: 0.1254 - val_accuracy: 0.9638 - val_loss: 0.1148
# Epoch 52/100
# 1171/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9569 - loss: 0.1210
# Epoch 52: val_accuracy did not improve from 0.96772
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9569 - loss: 0.1211 - val_accuracy: 0.9632 - val_loss: 0.1182
# Epoch 53/100
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9556 - loss: 0.1204
# Epoch 53: val_accuracy did not improve from 0.96772
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9556 - loss: 0.1204 - val_accuracy: 0.9645 - val_loss: 0.1145
# Epoch 54/100
# 1171/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9537 - loss: 0.1215
# Epoch 54: val_accuracy did not improve from 0.96772
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.9537 - loss: 0.1215 - val_accuracy: 0.9642 - val_loss: 0.1177
# Epoch 55/100
# 1173/1174 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9553 - loss: 0.1203
# Epoch 55: val_accuracy improved from 0.96772 to 0.96953, saving model to C:/Users/s/Desktop/Skin-Cancer-Prediction-main/SOURCE CODE/model/skin.keras
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.9553 - loss: 0.1203 - val_accuracy: 0.9695 - val_loss: 0.1057

# %%
import matplotlib.pyplot as plt
model.evaluate(Xtrain, Ytrain)
model.evaluate(Xtest, Ytest)
# Out:
# 1174/1174 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.9839 - loss: 0.0570
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9692 - loss: 0.0961
# [0.10421482473611832, 0.9677213430404663]

# %%
history_dict = history.history

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.title('Training and Validation Loss over Epochs') 
plt.grid(True) 
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.title('Training and Validation Accuracy over Epochs')
plt.xlabel('Epochs') 
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Generate predicted probabilities for the test set
from sklearn.metrics import classification_report


y_pred_prob_test = model.predict(Xtest)
# Convert probabilities to class labels
y_pred_test = np.argmax(y_pred_prob_test, axis=1)

# Print classification report
print("Classification Report:")
print(classification_report(Ytest, y_pred_test))
# Out:
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1314
#            1       0.99      1.00      0.99      1346
#            2       0.93      0.97      0.95      1361
#            3       1.00      1.00      1.00      1350
#            4       0.93      0.85      0.89      1326
#            5       1.00      1.00      1.00      1371
#            6       0.93      0.96      0.94      1319
#
#     accuracy                           0.97      9387
#    macro avg       0.97      0.97      0.97      9387
# weighted avg       0.97      0.97      0.97      9387

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate predicted probabilities for the test set
y_pred_prob_test = model.predict(Xtest)
# Convert probabilities to class labels
y_pred_test = np.argmax(y_pred_prob_test, axis=1)

# Generate confusion matrix
cm = confusion_matrix(Ytest, y_pred_test)

# Plot confusion matrix
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step

# %%
# Get the counts of different skin cancer types
skin_cancer_counts = meta_df['dx'].value_counts()

# Plot the bar graph
plt.figure(figsize=(6, 4))
skin_cancer_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of Different Types of Skin Cancer')
plt.xlabel('Skin Cancer Types')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
